# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Melbourne house-prices data.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.tail()
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 23673  Wyndham Vale   25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale  19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie      17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville        6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville     33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 23673      Harcourts  26-08-2017      27.2    3024.0  ...       1.0  0.0
# 23674  hockingstuart  26-08-2017      27.2    3024.0  ...       NaN  NaN
# 23675     Buckingham  26-08-2017      12.7    3085.0  ...       3.0  2.0
# 23676        Village  26-08-2017       6.3    3013.0  ...       1.0  1.0
# 23677        Village  26-08-2017       6.3    3013.0  ...       2.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %% [markdown]
#  1. Number of rows and columns in the dataset

# %%
df.shape
# Out:
# (23678, 21)

# %% [markdown]
#  2. Datatypes of each column

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# 3. Row indexes of rows having all null values

# %%
df[df['Price'].isnull()].index.tolist()
# Out:
# [0,
#  3,
#  7,
#  8,
#  9,
#  12,
#  13,
#  20,
#  31,
#  32,
#  35,
#  40,
#  48,
#  61,
#  65,
#  70,
#  122,
#  138,
#  140,
#  144,
#  151,
#  158,
#  161,
#  164,
#  165,
#  168,
#  170,
#  172,
#  174,
#  175,
#  176,
#  188,
#  189,
#  190,
#  195,
#  200,
#  204,
#  208,
#  212,
#  222,
#  228,
#  271,
#  275,
#  284,
#  292,
#  294,
#  306,
#  310,
#  317,
#  318,
#  336,
#  349,
#  359,
#  365,
#  370,
#  377,
#  379,
#  380,
#  382,
#  385,
#  386,
#  392,
#  396,
#  397,
#  398,
#  399,
#  402,
#  405,
#  407,
#  409,
#  412,
#  413,
#  414,
#  416,
#  418,
#  420,
#  422,
#  423,
#  424,
#  425,
#  426,
#  428,
#  434,
#  435,
#  437,
#  440,
#  443,
#  444,
#  447,
#  448,
#  449,
#  451,
#  457,
#  460,
#  461,
#  464,
#  470,
#  471,
#  473,
#  476,
#  477,
#  483,
#  485,
#  489,
#  506,
#  508,
#  518,
#  524,
#  555,
#  561,
#  564,
#  569,
#  603,
#  610,
#  612,
#  622,
#  623,
#  628,
#  632,
#  634,
#  635,
#  640,
#  641,
#  642,
#  645,
#  652,
#  654,
# ...

# %% [markdown]
# 4. The total number of empty rows and their percentage in whole dataset and remove them

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'Price': df.columns,
                                 'percent_missing': percent_missing})

# %%
print (df['Price'])
print (df['Price'].isnull())
# Out:
# 0              NaN
# 1        1480000.0
# 2        1035000.0
# 3              NaN
# 4        1465000.0
#            ...
# 23673          NaN
# 23674          NaN
# 23675    1100000.0
# 23676    1285000.0
# 23677    1050000.0
# Name: Price, Length: 23678, dtype: float64
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 23673     True
# 23674     True
# 23675    False
# 23676    False
# 23677    False
# Name: Price, Length: 23678, dtype: bool

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'Rooms': df.columns,
                                 'percent_missing': percent_missing})
print (df['Rooms'])
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        3.0
#         ...
# 23673    3.0
# 23674    4.0
# 23675    4.0
# 23676    4.0
# 23677    4.0
# Name: Rooms, Length: 23678, dtype: float64

# %%
df['Address'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23673    False
# 23674    False
# 23675    False
# 23676    False
# 23677    False
# Name: Address, Length: 23678, dtype: bool

# %%
((df.isnull() | df.isna()).sum() * 100 / df.index.size).round(2)
# Out:
# Suburb            0.55
# Address           0.55
# Rooms             0.55
# Type              0.55
# Price            22.31
# Method            0.55
# SellerG           0.55
# Date              0.55
# Distance          0.56
# Postcode          0.56
# Bedroom2         19.48
# Bathroom         19.49
# Car              20.09
# Landsize         26.47
# BuildingArea     57.69
# YearBuilt        51.26
# CouncilArea      33.88
# Lattitude        18.73
# Longtitude       18.73
# Regionname        0.56
# Propertycount     0.56
# dtype: float64

# %%
df=df.drop(columns=['BuildingArea','YearBuilt','CouncilArea'])

# %%
df
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  23547.000000  1.839600e+04  23546.000000  23546.000000  19066.000000
# mean       2.976048  1.056697e+06     10.306515   3109.782893      2.951956
# std        0.974501  6.419217e+05      6.016318     94.522190      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.330000e+05      6.200000   3047.000000      2.000000
# 50%        3.000000  8.800000e+05      9.500000   3101.000000      3.000000
# 75%        4.000000  1.302000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize     Lattitude    Longtitude  \
# count  19063.000000  18921.000000   17410.000000  19243.000000  19243.000000
# mean       1.570897      1.626235     551.783458    -37.812434    145.000287
# ...
